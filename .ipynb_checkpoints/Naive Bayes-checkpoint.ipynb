# %% [markdown]
# # Guassian Naive Bayes Classifier

# %% [markdown]
# This classifier can be fit with or without a maximum likelihood estimation which is used to find the posterior probability of a datapoint conditioned on a class. The class priors can also be set in advance. There is also a threshold paramter.

# %%
#creates a class of functions for the Gaussian Naive Bayes Classifier including a fit function,
#a predict function and a function that returns the probabilites of every tuple in every class
#the classifier also works for non-binary data

class naivebayes:
    
    
    def __init__(self):
        self.var_mean = {}
        self.prob_c = {}
        self.attribute_probabilities = []
        self.t = None
    
    #X and y inputs must be pandas dataframe or numpy arrays    
    def fit(self,X,y, mle = True, priors = [], t = None):
        import numpy as np
        #find unique classes
        labels = np.unique(y)
        self.t = t
        #estimate class priors with the option to use predefined priors
        if priors == []:
            probabilities_of_c = [float(sum(c == y))/len(y) for c in labels]
        else:
            probabilities_of_c = priors
        #append class probabilities into predefined dictionary
        for n,label in enumerate(labels):
            self.prob_c[label] = probabilities_of_c[n]
        
                   
        #variance and mean for each attribute in a class
        for label in labels:
            self.var_mean[label] = []
            matching = X[np.where(y == label)]
            for i in range(len(matching[0])):
                # m is the "coefficient" for the maximum likelihood estimation of variance
                if mle == True:
                    m = (len(matching.take(i,1)) - 1 )/ len(matching.take(i,1))
                else:
                    m = 1
                var = np.var(matching.take(i,1), ddof = 1) * m
                mean = np.mean(matching.take(i,1))
                self.var_mean[label].append([var,mean])       
                
    #Predicts labels given a set of vectors, either numpy arrays or pandas series
    def gauss_predict(self, vectors):
        import numpy as np
        self.attribute_probabilities = []
        
        #calculate datapoints' probability given a label of class c
        labels = []
        for i in self.prob_c.keys():
            attribute_probability = []
            for n in range(len(vectors[0])):
                var = self.var_mean[i][n][0]
                mean = self.var_mean[i][n][1]
                #I split up the calculation below so that it was tidier/easier to read
                coefficient = 1.0 / ((2.0*np.pi*var)**0.5)
                gauss = lambda x:coefficient * (np.e**(-((x - mean)**2.0)/(2.0*var)))
                #applies the gaussian probability to each datapoint in an attribute
                ap = [gauss(d) for d in vectors.take(n,1)]
                attribute_probability.append(ap)
            #finds the product of all conditionally independent probabilities
            attribute_probability = np.prod(attribute_probability,axis = 0)
            #multiplies each probability by the class prior probability
            attribute_probability = attribute_probability * self.prob_c[i]
            self.attribute_probabilities.append(attribute_probability)
        attribute_probabilities = np.array(self.attribute_probabilities)
        #Prediction 
        classes = [i for i in self.prob_c.keys()]
        #predicts without threshold; the main thing here is that the probabilities don't have 
        #to be normalized because they're not compared against a user-inputted number
        if self.t is None:
            for i in range(len(attribute_probabilities[0])):
                if attribute_probabilities[0][i] > attribute_probabilities[1][i]:
                    labels.append(classes[0])
                if attribute_probabilities[0][i] < attribute_probabilities[1][i]:
                    labels.append(classes[1])
            return labels 
        else:
            for i in range(len(attribute_probabilities[0])):
            #this was added for ease of thresholding against a user-inputted number
                total_prob = sum(attribute_probabilities.take(i,1))
                normalized_ap = attribute_probabilities.take(i,1)/total_prob
            #determine label
                biggest_prob = max(normalized_ap)
                label = int(np.where(attribute_probabilities == max(attribute_probabilities.take(i,1)))[0][0])
            #thresholding
                if biggest_prob < self.t and label == 0: 
                    labels.append(1)    
                else:
                    labels.append(classes[label])
            return labels 
    
    #shows the probabilities for each class for each datapoint
    def predict_proba(self, vectors):
        import numpy as np
        self.gauss_predict(vectors)
        attribute_probabilities = np.array(self.attribute_probabilities)
        normalized_ap = []
        #this ensures that the probabilities sum to 1
        for i in range(len(attribute_probabilities[0])):
            total_prob = sum(attribute_probabilities.take(i,1))
            normalized_ap.append(attribute_probabilities.take(i,1)/total_prob)
        probs = np.array([[i[0],i[1]] for i in normalized_ap])
        return probs

# %% [markdown]
# # Import data and scale it

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv', delimiter = ';')
q = lambda x:1 if x>= 7 else 0
df['binary_quality'] = df['quality'].apply(q)
data = df[[ 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'sulphates']]
labels = df['binary_quality']

from sklearn.preprocessing import scale, StandardScaler

scaled_data = scale(data, axis = 0)

# %% [markdown]
# # Run the model here!
#
# To run the model just run the two blocks of code above and the block of code below

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedKFold
nb = naivebayes()
features = ['volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
        'sulphates', 'alcohol']
d = df[features]
X = scale(d, axis = 0)
y = df['binary_quality']
skf = StratifiedKFold(n_splits=10)
myp = []
myr = []
mya = []
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index] 
    nb.fit(X_train,y_train)
    y_pred = nb.gauss_predict(X_test)
    myp.append(precision_score(y_test, y_pred))
    myr.append(recall_score(y_test, y_pred))
    mya.append(accuracy_score(y_test, y_pred))
print(f'After 10 folds the average accuracy is {np.mean(mya)}, the average precison is {np.mean(myp)}, and the average recall is {np.mean(myr)}.')
# Out:
# After 10 folds the average accuracy is 0.8405188679245283, the average precison is 0.5141662758802951, and the average recall is 0.6281385281385281.

# %% [markdown]
# # Everything below is the code I used to compare models, experiment, and evaluate models.

# %% [markdown]
# # My model vs. Baseline model
#
# The code block below was used to test my model against the baseline model. I used repeated stratified k-folds because my classifier runs much faster than the classifier of my teammates.

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.naive_bayes import GaussianNB
nb = naivebayes()
sk = GaussianNB()
features = ['volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
        'sulphates', 'alcohol']
d = df[features]
X = scale(d, axis = 0)
y = df['binary_quality']
rskf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10,
    random_state=119)
myp = []
myr = []
mya = []
skp = []
skr = []
ska = []
prob_error = []
for train_index, test_index in rskf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index] 
    nb.fit(X_train,y_train)
    sk.fit(X_train,y_train)
    y_pred = nb.gauss_predict(X_test)
    sky_pred = sk.predict(X_test)
    avg_error = sum(nb.predict_proba(X_test).take(1,1) - sk.predict_proba(X_test).take(1,1)) / len(nb.predict_proba(X_test).take(1,1))
    prob_error.append(avg_error)
    myp.append(precision_score(y_test, y_pred))
    myr.append(recall_score(y_test, y_pred))
    mya.append(accuracy_score(y_test, y_pred))
    skp.append(precision_score(y_test, sky_pred))
    skr.append(recall_score(y_test, sky_pred))
    ska.append(accuracy_score(y_test, sky_pred))

# %%
print(np.std(myp, ddof = 1),np.std(myr, ddof = 1)) 
print(np.std(skp, ddof = 1),np.std(skr, ddof = 1))
# Out:
# 0.07695160505470501 0.091900243750603
# 0.07695160505470501 0.091900243750603

# %% [markdown]
# I wanted to get a look at how close my probabilities were to the baseline models. I didn't put this table in the final report. Instead I calculated the mean and standard deviation of the differences between my probabilities and the baseline probabilites.

# %%
import pandas as pd
s = sk.predict_proba(X_test)
prob_dict = {'Naive Bayes':p.take(1,1)[:20],
             'Baseline Naive Bayes':s.take(1,1)[:20]}
prob_df = pd.DataFrame(prob_dict)
print(prob_df.to_latex(index=False))
# Out:
# \begin{tabular}{rr}
# \toprule
#  Naive Bayes &  Baseline Naive Bayes \\
# \midrule
#     0.685572 &          5.237637e-03 \\
#     0.829097 &          1.147819e-01 \\
#     0.834901 &          5.829068e-03 \\
#     0.149748 &          1.280329e-03 \\
#     0.653692 &          3.402020e-03 \\
#     0.000756 &          3.064171e-03 \\
#     0.011361 &          2.856551e-02 \\
#     0.005497 &          1.296422e-02 \\
#     0.005635 &          2.289331e-02 \\
#     0.639932 &          3.777910e-01 \\
#     0.653692 &          2.004498e-03 \\
#     0.565574 &          7.509674e-04 \\
#     0.207216 &          1.084762e-02 \\
#     0.004920 &          7.755072e-27 \\
#     0.586015 &          1.185444e-01 \\
#     0.005993 &          5.958225e-04 \\
#     0.026228 &          2.056591e-02 \\
#     0.004920 &          2.880030e-03 \\
#     0.334233 &          2.952646e-04 \\
#     0.924652 &          1.517964e-03 \\
# \bottomrule
# \end{tabular}
# ...

# %%
print(np.mean(prob_error), np.std(prob_error, ddof = 1), sem(prob_error))
# Out:
# 9.040035705895083e-11 1.9929582579398673e-11 1.9929582579398674e-12

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.figure(figsize = (3.5,6))
h = [np.mean(prob_error)]
x = [i for i in range(len(h))]
plt.bar(x,h, yerr = [np.std(prob_error, ddof = 1)], 
        capsize = 5, align = 'center', width = 0.5)
plt.xlabel('Mean Difference', fontsize = 12)
#ticks = ['Naive Bayes']
#plt.xticks(x,ticks, fontsize = 8, rotation = 45)
#plt.yticks(ticks,ticks, fontsize = 8)
plt.tight_layout()
plt.title('Mean Difference in Probabilites of Positive Class',fontsize = 14)
plt.annotate('Mean $\pm$ SEM, \n n-folds = 100',xy = (0.1,0.2), fontsize = 12)
plt.savefig('mean_difference_bar_graph.png', bbox_inches='tight' )

# %% [markdown]
# A table I created for the implementation report

# %%
import pandas as pd
from scipy.stats import sem
eval_dict = {'Method':['Naive Bayes','Baseline Naive Bayes'], 
             'Mean Precision':[np.mean(myp),np.mean(skp)], 'Precision SEM':[sem(myp), sem(skp)],
             'Mean Recall':[np.mean(myr),np.mean(skr)], 'Recall SEM':[sem(myr), sem(skr)]}
eval_df = pd.DataFrame(eval_dict)
print(eval_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#               Method &  Mean Precision &  Precision SEM &  Mean Recall &  Recall SEM \\
# \midrule
#          Naive Bayes &        0.459936 &       0.007695 &      0.63026 &     0.00919 \\
# Baseline Naive Bayes &        0.459936 &       0.007695 &      0.63026 &     0.00919 \\
# \bottomrule
# \end{tabular}
# /var/folders/hl/t7n7c3hn5cg8q9rg7d8dp3lh0000gn/T/ipykernel_98838/142407668.py:7: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(eval_df.to_latex(index=False))

# %%
eval_df
# Out:
#                  Method  Mean Precision  Precision SEM  Mean Recall  \
# 0           Naive Bayes        0.437899       0.007255     0.655563
# 1  Baseline Naive Bayes        0.459936       0.007695     0.630260
#
#    Recall SEM
# 0     0.00932
# 1     0.00919

# %%
from sklearn import metrics
import seaborn as sns
index = [i for i in rskf.split(X,y)]
X_train, X_test = X[index[1][0]], X[index[1][1]]
y_train, y_test = y[index[1][0]], y[index[1][1]] 
sk.fit(X_train, y_train)
plt.figure(figsize = (6,3.5))
sns.set_style('white')
fpr, tpr, thresholds = metrics.roc_curve(y_test, sk.predict_proba(X_test)[:,1])
plt.plot(fpr,tpr)
#nb.fit(X_train,y_train, mle = False)
#fpr, tpr, thresholds = metrics.roc_curve(y_test, nb.predict_proba(X_test)[:,1])
#plt.plot(fpr,tpr)
nb.fit(X_train,y_train)
fpr, tpr, thresholds = metrics.roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.plot(fpr,tpr,  alpha = 0.5, linewidth = 5)
x = [i/100 for i in range(100)]
plt.plot(x,x)
plt.tight_layout()
plt.ylabel('TPR', fontsize = 8)
plt.xlabel('FPR',fontsize = 8)
#plt.title('ROC Curve for Naive Bayes Classifier', fontsize = 6)
plt.legend(["Baseline Naive Bayes", "Naive Bayes"])
area = round(metrics.roc_auc_score(y_test, nb.predict_proba(X_test)[:,1] ),4)
plt.annotate('Area = '+str(area),xy = (0.54,0.44))
plt.savefig('ROC curve.png')

# %% [markdown]
# # My model vs teammates model

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedKFold
nb = naivebayes()
features = ['volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
        'sulphates', 'alcohol']
d = df[features]
X = scale(d, axis = 0)
y = df['binary_quality']
skf = StratifiedKFold(n_splits=10)
myp = []
myr = []
mya = []
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index] 
    nb.fit(X_train,y_train)
    y_pred = nb.gauss_predict(X_test)
    myp.append(precision_score(y_test, y_pred, average = 'micro'))
    myr.append(recall_score(y_test, y_pred, average = 'micro'))
    mya.append(accuracy_score(y_test, y_pred))

# %%
print(np.std(myp, ddof = 1),sem(myp), np.std(myr, ddof = 1))
# Out:
# 0.07549131280096691 0.023872449200728084 0.07549131280096691

# %%
import pandas as pd
from scipy.stats import sem
eval_dict = {'Method':['Naive Bayes'], 
             'Mean Precision':[np.mean(myp)], 'Precision SEM':[sem(myp)],
             'Mean Recall':[np.mean(myr)], 'Recall SEM':[sem(myr)]}
eval_df = pd.DataFrame(eval_dict)
print(eval_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#      Method &  Mean Precision &  Precision SEM &  Mean Recall &  Recall SEM \\
# \midrule
# Naive Bayes &        0.840519 &       0.023872 &     0.840519 &    0.023872 \\
# \bottomrule
# \end{tabular}
# /var/folders/hl/t7n7c3hn5cg8q9rg7d8dp3lh0000gn/T/ipykernel_39061/3835777699.py:7: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(eval_df.to_latex(index=False))

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve
p = nb.predict_proba(X_test)
precision, recall, thresholds = precision_recall_curve(y_test, p.take(1,1))
plt.figure(figsize = (3,1.75))
plt.plot(recall,precision)
plt.xlabel('Recall (Positive Label: 1)', fontsize = 8)
plt.ylabel('Precision (Positive Label: 1)', fontsize = 8)
ticks = [0.25,0.5,0.75,1.0]
plt.xticks(ticks,ticks, fontsize = 8)
plt.yticks(ticks,ticks, fontsize = 8)
plt.savefig('precision_recall_curve.png')

# %% [markdown]
# # Experiments
#
# Below are several experiments conducted in trying to find the best model.

# %% [markdown]
# The code block below is where I ran various experiments to test the model. This includes feature representation, thresholding, maximum likelihood estimation, and prior probabilities. What remains is the experiment for feature representation with some of the iterations commented out.

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, confusion_matrix, accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
import matplotlib.pyplot as plt
#import itertools
#combos = itertools.combinations(range(11), 9)
#t1 = [i/100 for i in range(10,100,1)]
nb = naivebayes()

y = df['binary_quality']
avgp = []
avgr = []
avga = []
for combo in combos:
    features = [cols[i] for i in combo]
    d = df[features]
    X = scale(d, axis = 0)
    
    #skf = StratifiedKFold(n_splits=10, random_state=4, shuffle = True)
    rskf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10,
    random_state=34)
    myp = []
    myr = []
    mya = []
    for train_index, test_index in rskf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index] 
        nb.fit(X_train,y_train, priors = [0.907, 0.093])
        y_pred = nb.gauss_predict(X_test)
        myp.append(precision_score(y_test, y_pred))
        myr.append(recall_score(y_test, y_pred))
        mya.append(accuracy_score(y_test, y_pred))
    avgp.append(np.mean(myp))
    avgr.append(np.mean(myr))
    avga.append(np.mean(mya))

# %%
l = range(len(prob_error))
plt.figure(figsize = (12,7))
#plt.scatter(l,s.take(1,1), c = 'b')
#plt.scatter(l,p.take(1,1), alpha = 0.5, s = 200.0, c = 'r')
plt.plot(l,prob_error, marker = 'o')
plt.ylabel('Average difference between probabilities of the positive class')
plt.xlabel('Ordinal number of test tuple')
#plt.legend(['Baseline Naive Bayes','Naive Bayes'])
# Out:
# Text(0.5, 0, 'Ordinal number of test tuple')

# %%
plt.figure(figsize = (12,7))
plt.plot(c1, avgp)
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, threshold = 0.9')
plt.show()

# %%
plt.figure(figsize = (12,7))
plt.plot(c1, avgp, marker = 'o')
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, threshold = 0.9')
plt.show()

# %%
plt.figure(figsize = (12,7))
plt.plot(c1, avgp, marker = 'o')
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, threshold = 0.8')
plt.show()

# %%
plt.figure(figsize = (12,7))
plt.plot(c1, avgp, marker = 'o')
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, threshold = 0.8')
plt.show()

# %%
plt.figure(figsize = (12,7))
plt.plot(c1, avgp, marker = 'o')
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, threshold = 0.7')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(c1, avgp, marker = 'o')
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, threshold = 0.6')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(c1, avgp)
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.plot(c1[56], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][56], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, threshold = 0.6')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(c1, avgp)
plt.plot(c1,avgr)
plt.plot(c1,avga)
plt.plot(c1[54], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][54], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, threshold = 0.6')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(t1, avgp)
plt.plot(t1,avgr)
plt.plot(t1,avga)
plt.plot(t1[54], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][51], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(t1, avgp)
plt.plot(t1,avgr)
plt.plot(t1,avga)
plt.plot(t1[54], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][51], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, set priors')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(t1, avgp)
plt.plot(t1,avgr)
plt.plot(t1,avga)
plt.plot(t1[44], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][44], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, set priors, no fixed acidity')
plt.xlabel('threshold')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(t1, avgp)
plt.plot(t1,avgr)
plt.plot(t1,avga)
plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, set priors, no fixed acidity or pH')
plt.xlabel('threshold')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,7))
plt.plot(t1, avgp)
plt.plot(t1,avgr)
plt.plot(t1,avga)
plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('without MLE, set priors, no fixed acidity or pH or alcohol')
plt.xlabel('threshold')
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [i for i in range(55)]
plt.figure(figsize = (12,7))
plt.plot(x_values, avgp)
plt.plot(x_values,avgr)
plt.plot(x_values,avga)
#plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.xlabel('different feature reps in sets of 9')
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [i for i in range(165)]
plt.figure(figsize = (12,7))
plt.plot(x_values, avgp)
plt.plot(x_values,avgr)
plt.plot(x_values,avga)
#plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
#plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.xlabel('different feature reps in sets of 8')
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [i for i in range(len(avgp))]
plt.figure(figsize = (12,7))
plt.plot(x_values, avgp)
plt.plot(x_values,avgr)
plt.plot(x_values,avga)
#plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
#plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.xlabel('different feature reps in sets of 7')
plt.show()

# %%
import matplotlib.pyplot as plt

p_and_r = [[x,y] for x,y in zip(avgp,avgr) if x > 0.6]
p = [x[0] for x in p_and_r]
r = [x[1] for x in p_and_r]
x_values = [i for i in range(len(p))]
plt.figure(figsize = (12,7))
plt.scatter(x_values, p)
plt.scatter(x_values,r)
#plt.plot(x_values,avga)
#plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
#plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.xlabel('different feature reps in sets of 6')
plt.show()

# %%
np.where([(2*i*n)/(i+n) for i,n in zip(avgp,avgr)] == max([(2*i*n)/(i+n) for i,n in zip(avgp,avgr)]))
avgr[146]
# Out:
# 0.5618831168831169

# %%
import matplotlib.pyplot as plt

p_and_r = [[x,y] for x,y in zip(avgp,avgr) if y > 0.58]
p = [x[0] for x in p_and_r]
r = [x[1] for x in p_and_r]
x_values = [i for i in range(len(p))]
plt.figure(figsize = (12,7))
plt.scatter(x_values, p)
plt.scatter(x_values,r)
#plt.plot(x_values,avga)
#plt.plot(t1[43], [(2*i*n)/(i+n) for i,n in zip(avgp,avgr)][43], marker = 'o')
plt.legend(['precision','recall','accuracy'])
#plt.axvline(0.985)
plt.axhline(0.5)
#plt.xticks([i/100 for i in range(50,100,5)],[i/100 for i in range(50,100,5)], rotation = 45)
plt.title('with MLE, set priors')
plt.xlabel('different feature reps in sets of 9')
plt.show()

# %%
import pandas as pd
probs = nb.predict_proba(X_test)
below = [i[0] for i in probs]
above = [i[1] for i in probs]
df = pd.DataFrame({'Below Prob':below, 'Above average Prob':above})
y_clean = [i for i in y_test]
df['labels'] = y_clean
df['prediction'] = y_pred
df[ df['labels'] == 1]
df
# Out:
#      Below Prob  Above average Prob  labels  prediction
# 0      0.999861        1.392587e-04       0           1
# 1      1.000000        2.707592e-17       0           1
# 2      0.994660        5.340262e-03       0           1
# 3      0.993321        6.679209e-03       0           1
# 4      0.999884        1.163674e-04       0           1
# ..          ...                 ...     ...         ...
# 154    0.998308        1.691911e-03       0           1
# 155    0.802821        1.971791e-01       0           1
# 156    0.988128        1.187197e-02       0           1
# 157    0.851755        1.482447e-01       0           1
# 158    0.999017        9.834845e-04       0           1
#
# [159 rows x 4 columns]

# %% [markdown]
# # Evaluation for Midterm report
#
# Below is work I did on the model leading to the midterm report

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
nb = naivebayes()
X = scaled_data
y = df['binary_quality']
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold
rskf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10,
    random_state=34)
skp = []
myp = []
skr = []
myr = []
skprob = []
myprob = []
for train_index, test_index in rskf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index] 
    clf.fit(X_train, y_train)
    nb.fit(X_train,y_train)
    sk_y_pred = clf.predict(X_test)
    my_y_pred = nb.gauss_predict(X_test)
    skprob.append(clf.predict_proba(X_test))
    myprob.append(nb.predict_proba(X_test))
    skp.append(precision_score(y_test, sk_y_pred))
    myp.append(precision_score(y_test, my_y_pred))
    skr.append(recall_score(y_test, sk_y_pred))
    myr.append(recall_score(y_test, my_y_pred))

# %%
myp_nomle = []
myr_nomle = []
myprob_nomle = []
for train_index, test_index in rskf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index] 
    nb.fit(X_train,y_train, mle = False)
    my_y_pred = nb.gauss_predict(X_test)
    myprob_nomle.append(nb.predict_proba(X_test))
    myp_nomle.append(precision_score(y_test, my_y_pred))
    myr_nomle.append(recall_score(y_test, my_y_pred))

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy.stats import sem
sns.set_style('dark')
sk_error = sem(skp)
my_error = sem(myp) 
my_error_nomle = sem(myp_nomle) 
height = [np.mean(skp),np.mean(myp_nomle),np.mean(myp)]
plt.figure(figsize = (12,7))
plt.bar(x = [1,2,3],height = height, yerr = [sk_error, my_error_nomle, my_error], 
        capsize = 5, align = 'center', width = 0.5)
plt.xticks(ticks = [1,2,3], labels = ["Scikit Naive Bayes","Naive Bayes w/o MLE", 'Naive Bayes w/ MLE'], 
           fontsize = 14)
plt.ylabel("Precision", fontsize = 14)
plt.xlabel("Implementation", fontsize = 20)
plt.title('Average Precision',fontsize = 20)
plt.annotate('Mean $\pm$ SEM, \n n-folds = 10',xy = (1.35,0.2), fontsize = 14)
plt.tight_layout()
#plt.savefig('Barplot SK vs NB w MLE.png',bbox_inches='tight')

# %%
sk_error = sem(skr)
my_error = sem(myr) 
my_error_nomle = sem(myr_nomle) 
height = [np.mean(skr),np.mean(myr_nomle),np.mean(myr)]
plt.figure(figsize = (12,7))
plt.bar(x = [1,2,3],height = height, yerr = [sk_error, my_error_nomle, my_error], 
        capsize = 5, align = 'center', width = 0.5)
plt.xticks(ticks = [1,2,3], labels = ["Scikit Naive Bayes", 'Naive Bayes w/o MLE',"Naive Bayes with MLE"], 
           fontsize = 14)
plt.ylabel("Recall", fontsize = 14)
plt.xlabel("Implementation", fontsize = 20)
plt.title('Average Recall',fontsize = 20)
plt.annotate('Mean $\pm$ SEM, \n n-folds = 10',xy = (1.35,0.2), fontsize = 14)
plt.tight_layout()

# %%
p_table = pd.DataFrame({'n-fold':[i for i in range(1,101)],'Scikit':skp,
                        'Naive Bayes w/o MLE':myp_nomle,
                        'Naive Bayes w/ MLE':myp})
p_table.reset_index(drop = True, inplace = True)
avg_p_table = pd.DataFrame({'Method':["Scikit Naive Bayes", 
                            'Naive Bayes w/o MLE',"Naive Bayes with MLE"],
                'Mean Precision':[np.mean(skp),np.mean(myp_nomle),np.mean(myp)],
                 'SEM':[sem(skp),sem(myp_nomle),sem(myp)]})
avg_p_table
print(avg_p_table.to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
#               Method &  Mean Precision &      SEM \\
# \midrule
#   Scikit Naive Bayes &        0.443412 & 0.006499 \\
#  Naive Bayes w/o MLE &        0.442805 & 0.006500 \\
# Naive Bayes with MLE &        0.443412 & 0.006499 \\
# \bottomrule
# \end{tabular}
# /var/folders/hl/t7n7c3hn5cg8q9rg7d8dp3lh0000gn/T/ipykernel_85098/39771918.py:10: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(avg_p_table.to_latex(index=False))

# %%
sum(p_table['Naive Bayes w/ MLE'] > p_table[ 'Naive Bayes w/o MLE'])
# Out:
# 13

# %%
r_table = pd.DataFrame({'n-fold':[i for i in range(1,11)],'Scikit':skr,
                        'Naive Bayes w/o MLE':myr_nomle,
                        'Naive Bayes w/ MLE':myr})
r_table.reset_index(drop = True, inplace = True)
r_table
# Out:
#    n-fold    Scikit  Naive Bayes w/o MLE  Naive Bayes w/ MLE
# 0       1  0.380952             0.380952            0.380952
# 1       2  0.428571             0.428571            0.428571
# 2       3  0.863636             0.863636            0.863636
# 3       4  0.863636             0.818182            0.863636
# 4       5  0.545455             0.545455            0.545455
# 5       6  0.772727             0.772727            0.772727
# 6       7  0.636364             0.681818            0.636364
# 7       8  0.636364             0.636364            0.636364
# 8       9  0.727273             0.727273            0.727273
# 9      10  0.571429             0.571429            0.571429

# %%
avg_r_table = pd.DataFrame({'Method':["Scikit Naive Bayes", 
                            'Naive Bayes w/o MLE',"Naive Bayes with MLE"],
                'Mean Recall':[np.mean(skr),np.mean(myr_nomle),np.mean(myr)],
                 'SEM':[sem(skr),sem(myr_nomle),sem(myr)]})
avg_r_table
print(avg_r_table.to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
#               Method &  Mean Recall &      SEM \\
# \midrule
#   Scikit Naive Bayes &     0.666623 & 0.009555 \\
#  Naive Bayes w/o MLE &     0.663420 & 0.009533 \\
# Naive Bayes with MLE &     0.666623 & 0.009555 \\
# \bottomrule
# \end{tabular}
# /var/folders/hl/t7n7c3hn5cg8q9rg7d8dp3lh0000gn/T/ipykernel_85098/696424690.py:6: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(avg_r_table.to_latex(index=False))

# %%
avg_table = pd.DataFrame({'Method':["Scikit Naive Bayes", 
                            'Naive Bayes w/o MLE',"Naive Bayes with MLE"],
                'Mean Precision':[np.mean(skp),np.mean(myp_nomle),np.mean(myp)],
                 'Precision SEM':[sem(skp),sem(myp_nomle),sem(myp)]})
avg_table['Mean Recall'] = [np.mean(skr),np.mean(myr_nomle),np.mean(myr)]
avg_table['Recall SEM'] = [sem(skr),sem(myr_nomle),sem(myr)]
avg_table
print(avg_table.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#               Method &  Mean Precision &  Precision SEM &  Mean Recall &  Recall SEM \\
# \midrule
#   Scikit Naive Bayes &        0.443412 &       0.006499 &     0.666623 &    0.009555 \\
#  Naive Bayes w/o MLE &        0.442805 &       0.006500 &     0.663420 &    0.009533 \\
# Naive Bayes with MLE &        0.443412 &       0.006499 &     0.666623 &    0.009555 \\
# \bottomrule
# \end{tabular}
# /var/folders/hl/t7n7c3hn5cg8q9rg7d8dp3lh0000gn/T/ipykernel_85098/3154035216.py:8: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(avg_table.to_latex(index=False))

# %%
one = {'Scikit':skprob[3][:,1], 
                        'Naive Bayes w/o MLE':myprob_nomle[3][:,1],
                        'Naive Bayes w/ MLE':myprob[3][:,1]}
two = {'Scikit':skprob[6][:,1], 
        'Naive Bayes w/o MLE':myprob_nomle[6][:,1],
        'Naive Bayes w/ MLE':myprob[6][:,1]}
df_one = pd.DataFrame(one)
df_two = pd.DataFrame(two)
prob_df = df_one.join(df_two, lsuffix='_caller', rsuffix='_other')

# %%
prob_df
# Out:
#      Scikit_caller  Naive Bayes w/o MLE_caller  Naive Bayes w/ MLE_caller  \
# 0         0.937214                    0.937533                   0.937214
# 1         0.382291                    0.378206                   0.382291
# 2         0.858499                    0.858452                   0.858499
# 3         0.765181                    0.762195                   0.765181
# 4         0.465993                    0.465325                   0.465993
# ..             ...                         ...                        ...
# 155       0.591041                    0.596929                   0.591041
# 156       0.979794                    0.979513                   0.979794
# 157       0.962995                    0.962526                   0.962995
# 158       0.979794                    0.979513                   0.979794
# 159       0.974910                    0.975698                   0.974910
#
#      Scikit_other  Naive Bayes w/o MLE_other  Naive Bayes w/ MLE_other
# ...

# %%
from sklearn import metrics
index = [i for i in rskf.split(X,y)]
X_train, X_test = X[index[1][0]], X[index[1][1]]
y_train, y_test = y[index[1][0]], y[index[1][1]] 
clf.fit(X_train, y_train)
plt.figure(figsize = (3,1.75))
sns.set_style('white')
fpr, tpr, thresholds = metrics.roc_curve(y_test, clf.predict_proba(X_test)[:,1])
plt.plot(fpr,tpr)
#nb.fit(X_train,y_train, mle = False)
#fpr, tpr, thresholds = metrics.roc_curve(y_test, nb.predict_proba(X_test)[:,1])
#plt.plot(fpr,tpr)
nb.fit(X_train,y_train)
fpr, tpr, thresholds = metrics.roc_curve(y_test, nb.predict_proba(X_test)[:,1])
plt.plot(fpr,tpr,  alpha = 0.5, linewidth = 5)
x = [i/100 for i in range(100)]
plt.plot(x,x)
plt.tight_layout()
plt.ylabel('TPR', fontsize = 8)
plt.xlabel('FPR',fontsize = 8)
#plt.title('ROC Curve for Naive Bayes Classifier', fontsize = 6)
plt.legend(["Scikit", "NB w/ MLE"])
area = round(metrics.roc_auc_score(y_test, nb.predict_proba(X_test)[:,1] ),4)
plt.annotate('Area = '+str(area),xy = (0.54,0.44))
plt.savefig('ROC curve.png')
